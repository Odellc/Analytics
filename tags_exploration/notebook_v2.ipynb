# %%
import os
import sys
from random import sample
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__
from dotenv import load_dotenv
import pandas as pd
import datetime
from dateutil import parser as date_parser
import json
from pprint import pprint
from functions_2 import *

# %%
# Environment vars
load_dotenv()
connect_str = os.getenv('AZURE_STORAGE_CONNECTION_STRING')

# %%
# Hardcoded date
today = datetime.datetime(year=2022, month=4, day=7)
today_str = datetime_string(today, "/")

# %%
# Instantiate blob service client
try:
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
except Exception as e:
    print(f'Unable to connect to BlobServiceClient: {e}')

# %%
# Get Amplitude tag information
source_name = "Redshift"
schema = "javascript"
_table = "filter_added"
table_name = f"{schema}{_table}"

amplitude_tags = get_invalid_json(
    blob_service_client, 
    "researchanalyticsinsights", 
    f"Unprocessed/{source_name}/{today_str}/{table_name}.json"
)

amplitude_tags = pd.DataFrame(amplitude_tags)

# %%
# filter out NA values
amplitude_tags = amplitude_tags[~amplitude_tags["field_name"].isnull()]

# Only include tag filter usage 
amplitude_tags = amplitude_tags[amplitude_tags["field_name"].str.contains("tag", case=False)]
amplitude_tags.head()
filter_tags = amplitude_tags.groupby("user_id")["id"].count().reset_index().rename(
    columns={
        "id": "event.filtered_by_tag_count",
        "user_id": "event.user_id"
    }
)
# filter_tags.head()

# %%
# Fetching users, accounts, and chargebee subscriptions.
# Merging all tables into one.
df = get_users_accounts_subscriptions_data(blob_service_client, today_str)
# Out:
# Fetching user data...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88329 entries, 3 to 90338
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id.$oid                           88329 non-null  object
#  1   accountId.$oid                     88329 non-null  object
#  2   language                           88289 non-null  float64
#  3   dateCreated.$date                  88329 non-null  int64
#  4   email                              88329 non-null  object
#  5   auth0Cache.usermetadata.lastName   88248 non-null  object
#  6   auth0Cache.usermetadata.firstName  88256 non-null  object
#  7   subscriptionType                   88329 non-null  object
#  8   isPrimary                          88329 non-null  bool
#  9   auth0Cache.usermetadata.demo       161 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(7)
# memory usage: 6.8+ MB
# None
# Fetching account data...
# Fetching Chargebee data...
# # of all active, paid accounts: (972, 41)
# Merging user and account table...
# Rows of users after merge: (42790, 51)
# Rows in users_df: (42790, 51)
# Rows in user per account (971, 2)
# Size of all users of active, paid accounts (42790, 53)

# %%
df["user|dateCreated.$date"].head()
df[df["user|dateCreated.$date"] != None].head()
# Out:
#            account|_id.$oid      account|name account|domain  \
# 0  5b14ee04854ff50007e2a077          Azavista       azavista
# 1  5b14ee04854ff50007e2a077          Azavista       azavista
# 2  5b1e3680d8c5b500075ecfd3  wetransform GmbH    wetransform
# 3  5b1e3680d8c5b500075ecfd3  wetransform GmbH    wetransform
# 4  5b1e3680d8c5b500075ecfd3  wetransform GmbH    wetransform
#
#    account|isActive  account|type  account|trialEnds.$date  \
# 0              True           1.0            1528897421000
# 1              True           1.0            1528897421000
# 2              True           1.0            1529311488473
# 3              True           1.0            1529311488473
# 4              True           1.0            1529311488473
#
#   account|dateCreated.$date      account|ownerId.$oid account|edition  \
# 0   2018-06-04 07:45:08.977  5b14ee05854ff50007e2a078   gtmhub-summit
# 1   2018-06-04 07:45:08.977  5b14ee05854ff50007e2a078   gtmhub-summit
# 2   2018-06-11 08:44:48.473  5b1e3680d8c5b500075ecfd4   gtmhub-summit
# 3   2018-06-11 08:44:48.473  5b1e3680d8c5b500075ecfd4   gtmhub-summit
# 4   2018-06-11 08:44:48.473  5b1e3680d8c5b500075ecfd4   gtmhub-summit
#
#   account|subscriptionId  ... user|language      user|dateCreated.$date  \
# 0      1mk51ZXQtzEmDUIfF  ...           0.0  2018-06-07 14:13:32.294000
# 1      1mk51ZXQtzEmDUIfF  ...           0.0         2018-06-04 07:45:09
# 2      1mkVvueQuePTWUOmB  ...           0.0  2018-06-11 08:44:48.498000
# 3      1mkVvueQuePTWUOmB  ...           0.0  2018-06-12 12:20:29.635000
# 4      1mkVvueQuePTWUOmB  ...           0.0  2019-06-25 15:40:06.882000
#
#                        user|email  user|auth0Cache.usermetadata.lastName  \
# 0                 jp@azavista.com                          van der Kuijl
# 1  gabriel.thomaidis@azavista.com                              Thomaidis
# 2               tr@wetransform.to                                  Reitz
# 3               st@wetransform.to                                Templer
# 4               ch@wetransform.to                                   Hönn
#
#   user|auth0Cache.usermetadata.firstName  user|subscriptionType  \
# 0                                     JP                regular
# 1                                Gabriel                regular
# 2                               Thorsten                regular
# 3                                  Simon                regular
# 4                            Christopher                regular
#
#   user|isPrimary user|auth0Cache.usermetadata.demo                account|id  \
# 0           True                               NaN  5b14ee04854ff50007e2a077
# 1           True                               NaN  5b14ee04854ff50007e2a077
# 2           True                               NaN  5b1e3680d8c5b500075ecfd3
# 3           True                               NaN  5b1e3680d8c5b500075ecfd3
# 4           True                               NaN  5b1e3680d8c5b500075ecfd3
#
#   account|users_count
# 0                   2
# 1                   2
# 2                   4
# 3                   4
# 4                   4
#
# [5 rows x 53 columns]

# %%
# Last 60 days
threshold_date = today - datetime.timedelta(days=180)

# %%
# Filter on users created at least 60 days ago
df = df[df["user|dateCreated.$date"] <= threshold_date]

# %%
# Join event data to df
df = df.merge(
    filter_tags,
    how="inner",
    left_on="user|_id.$oid",
    right_on="event.user_id"
)

# %%
df.head()
# Out:
#            account|_id.$oid          account|name account|domain  \
# 0  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 1  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 2  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 3  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 4  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
#
#    account|isActive  account|type  account|trialEnds.$date  \
# 0              True           1.0            1543449600000
# 1              True           1.0            1543449600000
# 2              True           1.0            1543449600000
# 3              True           1.0            1543449600000
# 4              True           1.0            1543449600000
#
#   account|dateCreated.$date      account|ownerId.$oid       account|edition  \
# 0   2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 1   2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 2   2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 3   2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 4   2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
#
#   account|subscriptionId  ...                            user|email  \
# 0      1mk51YnR7UCENkTmG  ...    eduard.bechler@oms-pruefservice.de
# 1      1mk51YnR7UCENkTmG  ...      florian.kern@oms-pruefservice.de
# 2      1mk51YnR7UCENkTmG  ...      kathrin.west@oms-pruefservice.de
# 3      1mk51YnR7UCENkTmG  ...      lars.thanner@oms-pruefservice.de
# 4      1mk51YnR7UCENkTmG  ...  julia.schroedter@oms-pruefservice.de
#
#    user|auth0Cache.usermetadata.lastName  \
# 0                                Bechler
# 1                                   Kern
# 2                                   West
# 3                                Thanner
# 4                                 Seiter
#
#   user|auth0Cache.usermetadata.firstName  user|subscriptionType  \
# 0                                 Eduard                regular
# 1                                Florian                regular
# 2                                Kathrin                regular
# 3                                   Lars                regular
# 4                                  Julia                regular
#
#   user|isPrimary  user|auth0Cache.usermetadata.demo                account|id  \
# 0           True                                NaN  5bd1a35727eb330001800428
# 1           True                                NaN  5bd1a35727eb330001800428
# 2           True                                NaN  5bd1a35727eb330001800428
# 3           True                                NaN  5bd1a35727eb330001800428
# 4           True                                NaN  5bd1a35727eb330001800428
#
#   account|users_count             event.user_id event.filtered_by_tag_count
# 0                 780  5c29bc403d53e90001ade104                           2
# 1                 780  5c29c0913d53e90001ade1d6                           1
# 2                 780  5c29c8a636973a00016ceca5                           1
# 3                 780  5c29c8a53d53e90001ade3c3                           1
# 4                 780  5c3726588f005100015ce486                          18
#
# [5 rows x 55 columns]

# %%
df.shape
# Out:
# (975, 55)

# %%
# Read in CSDA data
csda_df = pd.read_csv(os.path.join(os.pardir, "shared_data", "csda_salesforce_export.csv"))

# Rename columns
csda_df.columns = [
    "_".join(column.lower().split())
    for column in csda_df.columns
]

# Add prefix for clarity after join
csda_df = csda_df.add_prefix("salesforce|")

# %%
# Left join CSDA table with main dataframe (df)
df = df.merge(
    csda_df,
    how="left",
    left_on="account|_id.$oid",
    right_on="salesforce|chargebee_id"
)

# %%
# Get Hubspot data
hubspot_df = get_hubspot_data()
# Out:
# Fetching Hubspot data...
# Hubspot contacts...
# Hubspot companies...

# %%
# Merge users with HubSpot data
df = df.merge(
    hubspot_df,
    how="left",
    left_on="user|email",
    right_on="hubspot|email"
)

# %%
# Add CSDA column
df["salesforce|team_member_name"] = df["salesforce|team_member_name"].fillna("-")
df["salesforce|is_csda"] = df["salesforce|team_member_name"].map(
    lambda x: True if x != "-" else False
)

# %%
# Rename columns intended to be kept
column_name_remapping = {
    "account|_id.$oid": "account.id",
    "account|name": "account.name",
    "account|dateCreated.$date": "account.date_created",
    "chargebee|status": "chargebee.status",
    "user|_id.$oid": "user.id",
    "user|language": "user.language",
    "user|dateCreated.$date": "user.date_created",
    "user|email": "user.email",
    "user|auth0Cache.usermetadata.lastName": "user.last_name",
    "user|auth0Cache.usermetadata.firstName": "user.first_name",
    "account|users_count": "account.users_count",
    "hubspot|jobtitle": "hubspot.job_title",
    "hubspot|industry": "hubspot.industry",
    "hubspot|numberofemployees": "hubspot.number_of_employees",
    "salesforce|is_csda": "salesforce.is_csda",
    "hubspot|country": "hubspot.country",
    "event.filtered_by_tag_count": "event.filtered_by_tag_count"
}

# Keep only the keys of mapping columns
# df = df[column_name_remapping.keys()]

# Change names of columns based on mapping
df = df.rename(columns=column_name_remapping)

# %%
# Change language code to categorical
language_code_mapping = {
    0: "English",
    1: "German",
    2: "Chinese",
    3: "Bulgarian",
    4: "Spanish",
    5: "French",
    6: "Portuguese"
}

df = df.replace({"user.language": language_code_mapping})

# %%
df.head()
# Out:
#                  account.id          account.name account|domain  \
# 0  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 1  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 2  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 3  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 4  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
#
#    account|isActive  account|type  account|trialEnds.$date  \
# 0              True           1.0            1543449600000
# 1              True           1.0            1543449600000
# 2              True           1.0            1543449600000
# 3              True           1.0            1543449600000
# 4              True           1.0            1543449600000
#
#      account.date_created      account|ownerId.$oid       account|edition  \
# 0 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 1 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 2 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 3 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 4 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
#
#   account|subscriptionId  ... salesforce|renewal_date  salesforce|employees  \
# 0      1mk51YnR7UCENkTmG  ...              11/29/2021                 240.0
# 1      1mk51YnR7UCENkTmG  ...              11/29/2021                 240.0
# 2      1mk51YnR7UCENkTmG  ...              11/29/2021                 240.0
# 3      1mk51YnR7UCENkTmG  ...              11/29/2021                 240.0
# 4      1mk51YnR7UCENkTmG  ...              11/29/2021                 240.0
#
#   hubspot|associatedcompanyid                         hubspot|email  \
# 0                  7278533788    eduard.bechler@oms-pruefservice.de
# 1                  7278533788      florian.kern@oms-pruefservice.de
# 2                  7278533788      kathrin.west@oms-pruefservice.de
# 3                  7278533788      lars.thanner@oms-pruefservice.de
# 4                  7278533788  julia.schroedter@oms-pruefservice.de
#
#   hubspot.job_title  hubspot.industry hubspot.number_of_employees  \
# 0              None       Electronics                         240
# 1              None       Electronics                         240
# 2              None       Electronics                         240
# 3              None       Electronics                         240
# 4              None       Electronics                         240
#
#        hubspot|chargebee_id  hubspot.country salesforce.is_csda
# 0  5bd1a35727eb330001800428          Germany               True
# 1  5bd1a35727eb330001800428          Germany               True
# 2  5bd1a35727eb330001800428          Germany               True
# 3  5bd1a35727eb330001800428          Germany               True
# 4  5bd1a35727eb330001800428          Germany               True
#
# [5 rows x 72 columns]

# %%
# Fetch user_roles data
user_roles_df = get_user_roles_table(blob_service_client, today_str)
user_roles_df.head()
# Out:
#         user_roles._id.$oid    user_roles.userId.$oid  \
# 0  574e9259ed915d0006b985e5  574e9259ed915d0006b985e4
# 1  573e222fed915d0005cc2d07  573e222fed915d0005cc2d06
# 2  573d93d9ed915d00052efb6c  573d93d9ed915d00052efb6a
# 3  5746e3c8ed915d0005cc319c  5746e3c8ed915d0005cc319b
# 4  573f32bded915d0005cc2e5d  573f32bded915d0005cc2e5c
#
#      user_roles.roleId.$oid user_roles.accountId.$oid
# 0  573d93d9ed915d00052efb6b  574e9259ed915d0006b985e3
# 1  573d93d9ed915d00052efb6b  573e222fed915d0005cc2d05
# 2  573d93d9ed915d00052efb6b  573d93d9ed915d00052efb69
# 3  573d93d9ed915d00052efb6b  5746e3c8ed915d0005cc319a
# 4  573d93d9ed915d00052efb6b  573f32bded915d0005cc2e5b

# %%
# Fetch roles data
roles_df = get_roles_table(blob_service_client, today_str)
roles_df.head()
# Out:
#              roles._id.$oid             roles.name      roles.accountId.$oid
# 0  573dbb61ed915d0005cc2c4d                   user                       NaN
# 1  5a9f9cbee5274a0007acfcf9              Company B  57fb5f7bed915d0006582898
# 2  5b86ad85df457100079c04e4               Admin II  57fb5f7bed915d0006582898
# 3  5b8d2accf9159100080416a2  Air (bo's experiment)  573dbb12ed915d0005cc2c46
# 4  58f632d3ed915d0005e9ef6c              test role  58822288ed915d0005afa6ee

# %%
# Join user_roles with roles
user_roles_df = user_roles_df.merge(
    roles_df,
    how="left",
    left_on="user_roles.roleId.$oid",
    right_on="roles._id.$oid"
)

user_roles_df.head()
# Out:
#         user_roles._id.$oid    user_roles.userId.$oid  \
# 0  574e9259ed915d0006b985e5  574e9259ed915d0006b985e4
# 1  574e9259ed915d0006b985e5  574e9259ed915d0006b985e4
# 2  573e222fed915d0005cc2d07  573e222fed915d0005cc2d06
# 3  573e222fed915d0005cc2d07  573e222fed915d0005cc2d06
# 4  573d93d9ed915d00052efb6c  573d93d9ed915d00052efb6a
#
#      user_roles.roleId.$oid user_roles.accountId.$oid  \
# 0  573d93d9ed915d00052efb6b  574e9259ed915d0006b985e3
# 1  573d93d9ed915d00052efb6b  574e9259ed915d0006b985e3
# 2  573d93d9ed915d00052efb6b  573e222fed915d0005cc2d05
# 3  573d93d9ed915d00052efb6b  573e222fed915d0005cc2d05
# 4  573d93d9ed915d00052efb6b  573d93d9ed915d00052efb69
#
#              roles._id.$oid roles.name roles.accountId.$oid
# 0  573d93d9ed915d00052efb6b      admin                  NaN
# 1  573d93d9ed915d00052efb6b      admin                  NaN
# 2  573d93d9ed915d00052efb6b      admin                  NaN
# 3  573d93d9ed915d00052efb6b      admin                  NaN
# 4  573d93d9ed915d00052efb6b      admin                  NaN

# %%
unique_user_roles_df = get_roles_by_user(user_roles_df)
unique_user_roles_df.head()
# Out:
#      user_roles.userId.$oid                                              roles
# 0  573d9359ed915d00052efb10                                           SysAdmin
# 1  573d93d9ed915d00052efb6a                                              admin
# 2  573db6aeed915d0005cc2bc5                                              admin
# 3  573dbb12ed915d0005cc2c47  admin, user, user+, Ivan Osmak's team_7ba678c2...
# 4  573dbb61ed915d0005cc2c4c  admin, user, user+, Engineering_a8a9b5181dbd8f...

# %%
# Join df with user_roles_df
df = df.merge(
    unique_user_roles_df,
    how="left",
    left_on="user.id",
    right_on="user_roles.userId.$oid"
)

df.head()
# Out:
#                  account.id          account.name account|domain  \
# 0  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 1  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 2  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 3  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
# 4  5bd1a35727eb330001800428  OMS Prüfservice GmbH         growth
#
#    account|isActive  account|type  account|trialEnds.$date  \
# 0              True           1.0            1543449600000
# 1              True           1.0            1543449600000
# 2              True           1.0            1543449600000
# 3              True           1.0            1543449600000
# 4              True           1.0            1543449600000
#
#      account.date_created      account|ownerId.$oid       account|edition  \
# 0 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 1 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 2 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 3 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
# 4 2018-10-25 11:04:55.334  5bd1a35727eb330001800429  gtmhub-enterprise-v2
#
#   account|subscriptionId  ... hubspot|associatedcompanyid  \
# 0      1mk51YnR7UCENkTmG  ...                  7278533788
# 1      1mk51YnR7UCENkTmG  ...                  7278533788
# 2      1mk51YnR7UCENkTmG  ...                  7278533788
# 3      1mk51YnR7UCENkTmG  ...                  7278533788
# 4      1mk51YnR7UCENkTmG  ...                  7278533788
#
#                           hubspot|email hubspot.job_title  hubspot.industry  \
# 0    eduard.bechler@oms-pruefservice.de              None       Electronics
# 1      florian.kern@oms-pruefservice.de              None       Electronics
# 2      kathrin.west@oms-pruefservice.de              None       Electronics
# 3      lars.thanner@oms-pruefservice.de              None       Electronics
# 4  julia.schroedter@oms-pruefservice.de              None       Electronics
#
#   hubspot.number_of_employees      hubspot|chargebee_id hubspot.country  \
# 0                         240  5bd1a35727eb330001800428         Germany
# 1                         240  5bd1a35727eb330001800428         Germany
# 2                         240  5bd1a35727eb330001800428         Germany
# 3                         240  5bd1a35727eb330001800428         Germany
# 4                         240  5bd1a35727eb330001800428         Germany
#
#   salesforce.is_csda    user_roles.userId.$oid  \
# 0               True  5c29bc403d53e90001ade104
# 1               True  5c29c0913d53e90001ade1d6
# 2               True  5c29c8a636973a00016ceca5
# 3               True  5c29c8a53d53e90001ade3c3
# 4               True  5c3726588f005100015ce486
#
#                                                roles
# 0  User (Access, Manage OKR), Vertriebsgesellscha...
# 1  OKR Botschafter, O.U Stuttgart_6f5751189cad26d...
# 2  User (Access, Manage OKR), Lorch Sales Team Nü...
# 3                          User (Access, Manage OKR)
# 4  User (Access, Manage OKR), O.U Pforzheim_3d920...
#
# [5 rows x 74 columns]

# %%
df["roles"] = df["roles"].fillna("")
# df["user.is_okr_champion"] = df["roles"].map(lambda role: True if "champion" in (_role := role.lower()) or ("okr" in _role and "champion" in _role) else False)

# %%
# Drop unnecessary columns
"""
Should I drop all id's?
account.id
user.id

user_roles._id.$oid
user_roles.userId.$oid
user_roles.roleId.$oid
user_roles.accountId.$oid
roles._id.$oid
roles.accountId.$oid

"""

df = df[
    df.columns[
        ~df.columns.isin(
            [
                "account.id",
                "user.id",
                "user_roles._id.$oid",
                "user_roles.userId.$oid",
                "user_roles.roleId.$oid",
                "user_roles.accountId.$oid",
                "roles._id.$oid",
                "roles.accountId.$oid"
            ]
        )
    ]
]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 979 entries, 0 to 978
# Data columns (total 71 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   account.name                           979 non-null    object
#  1   account|domain                         979 non-null    object
#  2   account|isActive                       979 non-null    bool
#  3   account|type                           979 non-null    float64
#  4   account|trialEnds.$date                979 non-null    int64
#  5   account.date_created                   979 non-null    datetime64[ns]
#  6   account|ownerId.$oid                   979 non-null    object
#  7   account|edition                        979 non-null    object
#  8   account|subscriptionId                 979 non-null    object
#  9   account|planId                         979 non-null    object
#  10  account|subscription.mrr               182 non-null    float64
#  11  account|billingSystem                  182 non-null    object
#  12  account|language                       182 non-null    float64
#  13  account|modifiedById.$oid              182 non-null    object
#  14  account|modifiedAt.$date               182 non-null    float64
#  15  chargebee|id                           979 non-null    object
#  16  chargebee|currency_code                979 non-null    object
#  17  chargebee|trial_end                    942 non-null    float64
#  18  chargebee|customer_id                  979 non-null    object
#  19  chargebee.status                       979 non-null    object
#  20  chargebee|trial_start                  942 non-null    float64
#  21  chargebee|created_at                   979 non-null    int64
#  22  chargebee|started_at                   979 non-null    int64
#  23  chargebee|cancelled_at                 456 non-null    float64
#  24  chargebee|cancel_reason                0 non-null      object
#  25  chargebee|updated_at                   979 non-null    int64
#  26  chargebee|mrr                          979 non-null    float64
#  27  chargebee|deleted                      979 non-null    bool
#  28  chargebee|activated_at                 979 non-null    float64
#  29  chargebee|shipping_address.email       91 non-null     object
#  30  chargebee|shipping_address.phone       30 non-null     object
#  31  chargebee|shipping_address.line1       204 non-null    object
#  32  chargebee|shipping_address.city        204 non-null    object
#  33  chargebee|shipping_address.country     204 non-null    object
#  34  chargebee|shipping_address.first_name  196 non-null    object
#  35  chargebee|shipping_address.last_name   174 non-null    object
#  36  chargebee|invoice_notes                91 non-null     object
#  37  chargebee|exchange_rate                979 non-null    float64
#  38  chargebee|base_currency_code           979 non-null    object
#  39  chargebee|shipping_address.company     193 non-null    object
#  40  user|accountId.$oid                    979 non-null    object
#  41  user.language                          979 non-null    object
#  42  user.date_created                      979 non-null    object
#  43  user.email                             979 non-null    object
#  44  user.last_name                         979 non-null    object
#  45  user.first_name                        979 non-null    object
#  46  user|subscriptionType                  979 non-null    object
#  47  user|isPrimary                         979 non-null    bool
#  48  user|auth0Cache.usermetadata.demo      5 non-null      object
#  49  account|id                             979 non-null    object
#  50  account.users_count                    979 non-null    int64
#  51  event.user_id                          979 non-null    object
#  52  event.filtered_by_tag_count            979 non-null    int64
#  53  salesforce|account_name                705 non-null    object
#  54  salesforce|account_id                  705 non-null    object
#  55  salesforce|chargebee_id                705 non-null    object
#  56  salesforce|team_role                   705 non-null    object
#  57  salesforce|team_member_name            979 non-null    object
#  58  salesforce|account_owner               705 non-null    object
#  59  salesforce|expected_renewal_mrr        391 non-null    object
#  60  salesforce|renewal_date                665 non-null    object
#  61  salesforce|employees                   705 non-null    float64
#  62  hubspot|associatedcompanyid            239 non-null    object
#  63  hubspot|email                          244 non-null    object
#  64  hubspot.job_title                      124 non-null    object
#  65  hubspot.industry                       204 non-null    object
#  66  hubspot.number_of_employees            233 non-null    object
#  67  hubspot|chargebee_id                   167 non-null    object
#  68  hubspot.country                        200 non-null    object
#  69  salesforce.is_csda                     979 non-null    bool
#  70  roles                                  979 non-null    object
# dtypes: bool(4), datetime64[ns](1), float64(11), int64(6), object(49)
# memory usage: 523.9+ KB

# %%
df["user.date_created"] = df["user.date_created"].astype("datetime64[ns]")
df["account.date_created"] = df["account.date_created"].astype("datetime64[ns]")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 979 entries, 0 to 978
# Data columns (total 71 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   account.name                           979 non-null    object
#  1   account|domain                         979 non-null    object
#  2   account|isActive                       979 non-null    bool
#  3   account|type                           979 non-null    float64
#  4   account|trialEnds.$date                979 non-null    int64
#  5   account.date_created                   979 non-null    datetime64[ns]
#  6   account|ownerId.$oid                   979 non-null    object
#  7   account|edition                        979 non-null    object
#  8   account|subscriptionId                 979 non-null    object
#  9   account|planId                         979 non-null    object
#  10  account|subscription.mrr               182 non-null    float64
#  11  account|billingSystem                  182 non-null    object
#  12  account|language                       182 non-null    float64
#  13  account|modifiedById.$oid              182 non-null    object
#  14  account|modifiedAt.$date               182 non-null    float64
#  15  chargebee|id                           979 non-null    object
#  16  chargebee|currency_code                979 non-null    object
#  17  chargebee|trial_end                    942 non-null    float64
#  18  chargebee|customer_id                  979 non-null    object
#  19  chargebee.status                       979 non-null    object
#  20  chargebee|trial_start                  942 non-null    float64
#  21  chargebee|created_at                   979 non-null    int64
#  22  chargebee|started_at                   979 non-null    int64
#  23  chargebee|cancelled_at                 456 non-null    float64
#  24  chargebee|cancel_reason                0 non-null      object
#  25  chargebee|updated_at                   979 non-null    int64
#  26  chargebee|mrr                          979 non-null    float64
#  27  chargebee|deleted                      979 non-null    bool
#  28  chargebee|activated_at                 979 non-null    float64
#  29  chargebee|shipping_address.email       91 non-null     object
#  30  chargebee|shipping_address.phone       30 non-null     object
#  31  chargebee|shipping_address.line1       204 non-null    object
#  32  chargebee|shipping_address.city        204 non-null    object
#  33  chargebee|shipping_address.country     204 non-null    object
#  34  chargebee|shipping_address.first_name  196 non-null    object
#  35  chargebee|shipping_address.last_name   174 non-null    object
#  36  chargebee|invoice_notes                91 non-null     object
#  37  chargebee|exchange_rate                979 non-null    float64
#  38  chargebee|base_currency_code           979 non-null    object
#  39  chargebee|shipping_address.company     193 non-null    object
#  40  user|accountId.$oid                    979 non-null    object
#  41  user.language                          979 non-null    object
#  42  user.date_created                      979 non-null    datetime64[ns]
#  43  user.email                             979 non-null    object
#  44  user.last_name                         979 non-null    object
#  45  user.first_name                        979 non-null    object
#  46  user|subscriptionType                  979 non-null    object
#  47  user|isPrimary                         979 non-null    bool
#  48  user|auth0Cache.usermetadata.demo      5 non-null      object
#  49  account|id                             979 non-null    object
#  50  account.users_count                    979 non-null    int64
#  51  event.user_id                          979 non-null    object
#  52  event.filtered_by_tag_count            979 non-null    int64
#  53  salesforce|account_name                705 non-null    object
#  54  salesforce|account_id                  705 non-null    object
#  55  salesforce|chargebee_id                705 non-null    object
#  56  salesforce|team_role                   705 non-null    object
#  57  salesforce|team_member_name            979 non-null    object
#  58  salesforce|account_owner               705 non-null    object
#  59  salesforce|expected_renewal_mrr        391 non-null    object
#  60  salesforce|renewal_date                665 non-null    object
#  61  salesforce|employees                   705 non-null    float64
#  62  hubspot|associatedcompanyid            239 non-null    object
#  63  hubspot|email                          244 non-null    object
#  64  hubspot.job_title                      124 non-null    object
#  65  hubspot.industry                       204 non-null    object
#  66  hubspot.number_of_employees            233 non-null    object
#  67  hubspot|chargebee_id                   167 non-null    object
#  68  hubspot.country                        200 non-null    object
#  69  salesforce.is_csda                     979 non-null    bool
#  70  roles                                  979 non-null    object
# dtypes: bool(4), datetime64[ns](2), float64(11), int64(6), object(48)
# memory usage: 523.9+ KB

# %%
df.head()
# Out:
#            account.name account|domain  account|isActive  account|type  \
# 0  OMS Prüfservice GmbH         growth              True           1.0
# 1  OMS Prüfservice GmbH         growth              True           1.0
# 2  OMS Prüfservice GmbH         growth              True           1.0
# 3  OMS Prüfservice GmbH         growth              True           1.0
# 4  OMS Prüfservice GmbH         growth              True           1.0
#
#    account|trialEnds.$date    account.date_created      account|ownerId.$oid  \
# 0            1543449600000 2018-10-25 11:04:55.334  5bd1a35727eb330001800429
# 1            1543449600000 2018-10-25 11:04:55.334  5bd1a35727eb330001800429
# 2            1543449600000 2018-10-25 11:04:55.334  5bd1a35727eb330001800429
# 3            1543449600000 2018-10-25 11:04:55.334  5bd1a35727eb330001800429
# 4            1543449600000 2018-10-25 11:04:55.334  5bd1a35727eb330001800429
#
#         account|edition account|subscriptionId            account|planId  ...  \
# 0  gtmhub-enterprise-v2      1mk51YnR7UCENkTmG  gtmhub-enterprise-oms-1y  ...
# 1  gtmhub-enterprise-v2      1mk51YnR7UCENkTmG  gtmhub-enterprise-oms-1y  ...
# 2  gtmhub-enterprise-v2      1mk51YnR7UCENkTmG  gtmhub-enterprise-oms-1y  ...
# 3  gtmhub-enterprise-v2      1mk51YnR7UCENkTmG  gtmhub-enterprise-oms-1y  ...
# 4  gtmhub-enterprise-v2      1mk51YnR7UCENkTmG  gtmhub-enterprise-oms-1y  ...
#
#    salesforce|employees hubspot|associatedcompanyid  \
# 0                 240.0                  7278533788
# 1                 240.0                  7278533788
# 2                 240.0                  7278533788
# 3                 240.0                  7278533788
# 4                 240.0                  7278533788
#
#                           hubspot|email hubspot.job_title  hubspot.industry  \
# 0    eduard.bechler@oms-pruefservice.de              None       Electronics
# 1      florian.kern@oms-pruefservice.de              None       Electronics
# 2      kathrin.west@oms-pruefservice.de              None       Electronics
# 3      lars.thanner@oms-pruefservice.de              None       Electronics
# 4  julia.schroedter@oms-pruefservice.de              None       Electronics
#
#   hubspot.number_of_employees      hubspot|chargebee_id  hubspot.country  \
# 0                         240  5bd1a35727eb330001800428          Germany
# 1                         240  5bd1a35727eb330001800428          Germany
# 2                         240  5bd1a35727eb330001800428          Germany
# 3                         240  5bd1a35727eb330001800428          Germany
# 4                         240  5bd1a35727eb330001800428          Germany
#
#   salesforce.is_csda                                              roles
# 0               True  User (Access, Manage OKR), Vertriebsgesellscha...
# 1               True  OKR Botschafter, O.U Stuttgart_6f5751189cad26d...
# 2               True  User (Access, Manage OKR), Lorch Sales Team Nü...
# 3               True                          User (Access, Manage OKR)
# 4               True  User (Access, Manage OKR), O.U Pforzheim_3d920...
#
# [5 rows x 71 columns]

# %%
# Format datetime fields as string for output file
df["account.date_created"] = df["account.date_created"].dt.strftime("%Y/%m/%d")
df["user.date_created"] = df["user.date_created"].dt.strftime("%Y/%m/%d")

# %%
df.shape
# Out:
# (979, 71)

# %%
# Save data to csv file
df.to_csv(f"tag_filtering_users_data_{datetime_string(today, '-')}.csv", index=False)
