# %%
import os
import sys
from random import sample
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__
from dotenv import load_dotenv
import pandas as pd
import datetime
from dateutil import parser as date_parser
import json
from pprint import pprint
from functions_2 import *

# %%
# Environment vars
load_dotenv()
connect_str = os.getenv('AZURE_STORAGE_CONNECTION_STRING')

# %%
# Hardcoded date
today = datetime.datetime(year=2022, month=4, day=7)
today_str = datetime_string(today, "/")

# %%
# Instantiate blob service client
try:
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
except Exception as e:
    print(f'Unable to connect to BlobServiceClient: {e}')

# %%
# Fetching users, accounts, and chargebee subscriptions.
# Merging all tables into one.
df = get_users_accounts_subscriptions_data(blob_service_client, today_str)
# Out:
# Fetching user data...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88329 entries, 3 to 90338
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _id.$oid                           88329 non-null  object
#  1   accountId.$oid                     88329 non-null  object
#  2   language                           88289 non-null  float64
#  3   dateCreated.$date                  88329 non-null  int64
#  4   email                              88329 non-null  object
#  5   auth0Cache.usermetadata.lastName   88248 non-null  object
#  6   auth0Cache.usermetadata.firstName  88256 non-null  object
#  7   subscriptionType                   88329 non-null  object
#  8   isPrimary                          88329 non-null  bool
#  9   auth0Cache.usermetadata.demo       161 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(7)
# memory usage: 6.8+ MB
# None
# Fetching account data...
# Fetching Chargebee data...
# # of all active, paid accounts: (972, 41)
# Merging user and account table...
# Rows of users after merge: (42790, 51)
# Rows in users_df: (42790, 51)
# Rows in user per account (971, 2)
# Size of all users of active, paid accounts (42790, 53)

# %%
df["user|dateCreated.$date"].head()
df[df["user|dateCreated.$date"] != None].head()
# Out:
#            account|_id.$oid      account|name account|domain  \
# 0  5b14ee04854ff50007e2a077          Azavista       azavista
# 1  5b14ee04854ff50007e2a077          Azavista       azavista
# 2  5b1e3680d8c5b500075ecfd3  wetransform GmbH    wetransform
# 3  5b1e3680d8c5b500075ecfd3  wetransform GmbH    wetransform
# 4  5b1e3680d8c5b500075ecfd3  wetransform GmbH    wetransform
#
#    account|isActive  account|type  account|trialEnds.$date  \
# 0              True           1.0            1528897421000
# 1              True           1.0            1528897421000
# 2              True           1.0            1529311488473
# 3              True           1.0            1529311488473
# 4              True           1.0            1529311488473
#
#   account|dateCreated.$date      account|ownerId.$oid account|edition  \
# 0   2018-06-04 07:45:08.977  5b14ee05854ff50007e2a078   gtmhub-summit
# 1   2018-06-04 07:45:08.977  5b14ee05854ff50007e2a078   gtmhub-summit
# 2   2018-06-11 08:44:48.473  5b1e3680d8c5b500075ecfd4   gtmhub-summit
# 3   2018-06-11 08:44:48.473  5b1e3680d8c5b500075ecfd4   gtmhub-summit
# 4   2018-06-11 08:44:48.473  5b1e3680d8c5b500075ecfd4   gtmhub-summit
#
#   account|subscriptionId  ... user|language      user|dateCreated.$date  \
# 0      1mk51ZXQtzEmDUIfF  ...           0.0  2018-06-07 14:13:32.294000
# 1      1mk51ZXQtzEmDUIfF  ...           0.0         2018-06-04 07:45:09
# 2      1mkVvueQuePTWUOmB  ...           0.0  2018-06-11 08:44:48.498000
# 3      1mkVvueQuePTWUOmB  ...           0.0  2018-06-12 12:20:29.635000
# 4      1mkVvueQuePTWUOmB  ...           0.0  2019-06-25 15:40:06.882000
#
#                        user|email  user|auth0Cache.usermetadata.lastName  \
# 0                 jp@azavista.com                          van der Kuijl
# 1  gabriel.thomaidis@azavista.com                              Thomaidis
# 2               tr@wetransform.to                                  Reitz
# 3               st@wetransform.to                                Templer
# 4               ch@wetransform.to                                   Hönn
#
#   user|auth0Cache.usermetadata.firstName  user|subscriptionType  \
# 0                                     JP                regular
# 1                                Gabriel                regular
# 2                               Thorsten                regular
# 3                                  Simon                regular
# 4                            Christopher                regular
#
#   user|isPrimary user|auth0Cache.usermetadata.demo                account|id  \
# 0           True                               NaN  5b14ee04854ff50007e2a077
# 1           True                               NaN  5b14ee04854ff50007e2a077
# 2           True                               NaN  5b1e3680d8c5b500075ecfd3
# 3           True                               NaN  5b1e3680d8c5b500075ecfd3
# 4           True                               NaN  5b1e3680d8c5b500075ecfd3
#
#   account|users_count
# 0                   2
# 1                   2
# 2                   4
# 3                   4
# 4                   4
#
# [5 rows x 53 columns]

# %%
# Last 60 days
threshold_date = today - datetime.timedelta(days=60)

# %%
# Filter on users created at least 60 days ago
df = df[df["user|dateCreated.$date"] <= threshold_date]

# %%
# Number of unique users existing for at least 60 days
df.shape[0]
# Out:
# 35074

# %%
# Sample 250 users, but no more than 1 user per account

# Sample 250 unique accounts
sample_accounts = sample(df["account|_id.$oid"].unique().tolist(), 250)
# df = df[df["account|_id.$oid"].isin(sample_accounts)]

# Choose 1 user for each of the accounts sampled
sample_users = [
    sample(
        df[df["account|_id.$oid"] == acc]["user|_id.$oid"].tolist(), 
        1
    )[0]
    for acc in sample_accounts # sample(df["user|_id.$oid"].tolist(), 250)
]

len(sample_users)
# Out:
# 250

# %%
sample_users[:10]
# Out:
# ['60a7bedb58321a00010e969c',
#  '5f3ceb72fc68560001f9543d',
#  '61e55f0b0d823f000192d84f',
#  '5f185b989d29880001ba0140',
#  '60d0b5045535ee00013124bd',
#  '609072517453d2000154bfc2',
#  '5dc47cb0ee825700017381f9',
#  '610bdb2a61c125000103f96b',
#  '5eba5f58575a9e0001afd057',
#  '5df7bc05b874bc00018dfdac']

# %%
df = df[df["user|_id.$oid"].isin(sample_users)]

# %%
df.head()
# Out:
#               account|_id.$oid        account|name      account|domain  \
# 1015  5dbe9552fc535d0001015133              Advery              advery
# 1725  5836fdcbed915d0007090826       Prime Holding               prime
# 2502  5da59040f862dc0001f2ae06                Mews                mews
# 2671  5b4c5eacf85c070007d02b68             Solitea                 sbs
# 2841  5df25fa696e9cd00013ae7c0  Scruff of the Neck  scruff-of-the-neck
#
#       account|isActive  account|type  account|trialEnds.$date  \
# 1015              True           1.0            1573375954305
# 1725              True           1.0                        0
# 2502              True           1.0            1572511612000
# 2671              True           1.0            1532334329000
# 2841              True           1.0            1630367999000
#
#      account|dateCreated.$date      account|ownerId.$oid  account|edition  \
# 1015   2019-11-03 08:52:34.305  5dbe9552fc535d0001015134  gtmhub-start-v3
# 1725   2016-11-24 00:00:00.000  58939d52ed915d0005d0fb68       enterprise
# 2502   2019-10-15 09:24:16.957  5da59041f862dc0001f2ae07    gtmhub-summit
# 2671   2018-07-16 09:00:28.255  5b4c5eacf85c070007d02b69  gtmhub-start-v3
# 2841   2019-12-12 15:41:26.187  5df25fa696e9cd00013ae7c1  gtmhub-start-v3
#
#      account|subscriptionId  ... user|language      user|dateCreated.$date  \
# 1015    2sUBzx2uRgkVU1I1lWb  ...           1.0  2021-10-06 20:24:18.590000
# 1725       AzZdQbSagtvqqMHZ  ...           0.0  2018-11-05 12:01:12.621000
# 2502     2skdb1bJRexXTqJEYY  ...           0.0  2019-12-16 17:16:53.040000
# 2671      1mkVvrbQxx7oWuHGB  ...           0.0  2022-02-02 12:41:31.436000
# 2841      16A1AZRkSCuoW10SA  ...           0.0  2020-10-08 15:07:01.302000
#
#                             user|email  user|auth0Cache.usermetadata.lastName  \
# 1015          falk.kreuger@brueggli.ch
# 1725         bilyana.baycheva@sbnd.net                               Baycheva
# 2502           craig.bonafont@mews.com                               Bonafont
# 2671       marian.videka@mainstream.cz                                 Videka
# 2841  joe.cockburn@scruffoftheneck.com                               Cockburn
#
#      user|auth0Cache.usermetadata.firstName  user|subscriptionType  \
# 1015                           falk.kreuger                regular
# 1725                                Biliana                regular
# 2502                                  Craig                regular
# 2671                          marian.videka                regular
# 2841                                    Joe                regular
#
#      user|isPrimary user|auth0Cache.usermetadata.demo  \
# 1015           True                               NaN
# 1725           True                               NaN
# 2502           True                               NaN
# 2671           True                               NaN
# 2841           True                               NaN
#
#                     account|id account|users_count
# 1015  5dbe9552fc535d0001015133                  49
# 1725  5836fdcbed915d0007090826                   1
# 2502  5da59040f862dc0001f2ae06                  44
# 2671  5b4c5eacf85c070007d02b68                  96
# 2841  5df25fa696e9cd00013ae7c0                  11
#
# [5 rows x 53 columns]

# %%
df.shape
# Out:
# (250, 53)

# %%
# Read in CSDA data
csda_df = pd.read_csv(os.path.join(os.pardir, "shared_data", "csda_salesforce_export.csv"))

# Rename columns
csda_df.columns = [
    "_".join(column.lower().split())
    for column in csda_df.columns
]

# Add prefix for clarity after join
csda_df = csda_df.add_prefix("salesforce|")

# %%
# Left join CSDA table with main dataframe (df)
df = df.merge(
    csda_df,
    how="left",
    left_on="account|_id.$oid",
    right_on="salesforce|chargebee_id"
)

# %%
# Get Hubspot data
hubspot_df = get_hubspot_data()
# Out:
# Fetching Hubspot data...
# Hubspot contacts...
# Hubspot companies...

# %%
# Merge users with HubSpot data
df = df.merge(
    hubspot_df,
    how="left",
    left_on="user|email",
    right_on="hubspot|email"
)

# %%
# Add CSDA column
df["salesforce|team_member_name"] = df["salesforce|team_member_name"].fillna("-")
df["salesforce|is_csda"] = df["salesforce|team_member_name"].map(
    lambda x: True if x != "-" else False
)

# %%
# Rename columns intended to be kept
column_name_remapping = {
    "account|_id.$oid": "account.id",
    "account|name": "account.name",
    "account|dateCreated.$date": "account.date_created",
    "chargebee|status": "chargebee.status",
    "user|_id.$oid": "user.id",
    "user|language": "user.language",
    "user|dateCreated.$date": "user.date_created",
    "user|email": "user.email",
    "user|auth0Cache.usermetadata.lastName": "user.last_name",
    "user|auth0Cache.usermetadata.firstName": "user.first_name",
    "account|users_count": "account.users_count",
    "hubspot|jobtitle": "hubspot.job_title",
    "hubspot|industry": "hubspot.industry",
    "hubspot|numberofemployees": "hubspot.number_of_employees",
    "salesforce|is_csda": "salesforce.is_csda",
    "hubspot|country": "hubspot.country"
}

# Keep only the keys of mapping columns
df = df[column_name_remapping.keys()]

# Change names of columns based on mapping
df = df.rename(columns=column_name_remapping)

# %%
# Change language code to categorical
language_code_mapping = {
    0: "English",
    1: "German",
    2: "Chinese",
    3: "Bulgarian",
    4: "Spanish",
    5: "French",
    6: "Portuguese"
}

df = df.replace({"user.language": language_code_mapping})

# %%
df.head()
# Out:
#                  account.id        account.name    account.date_created  \
# 0  5dbe9552fc535d0001015133              Advery 2019-11-03 08:52:34.305
# 1  5836fdcbed915d0007090826       Prime Holding 2016-11-24 00:00:00.000
# 2  5da59040f862dc0001f2ae06                Mews 2019-10-15 09:24:16.957
# 3  5b4c5eacf85c070007d02b68             Solitea 2018-07-16 09:00:28.255
# 4  5df25fa696e9cd00013ae7c0  Scruff of the Neck 2019-12-12 15:41:26.187
#
#   chargebee.status                   user.id user.language  \
# 0           active  615e05f268dff200012d0cf7        German
# 1           active  5be031087b36380001172075       English
# 2           active  5df7bc05b874bc00018dfdac       English
# 3           active  61fa7bfb5498de00013e1689       English
# 4           active  5f7f2b15f7d6770001587b27       English
#
#             user.date_created                        user.email  \
# 0  2021-10-06 20:24:18.590000          falk.kreuger@brueggli.ch
# 1  2018-11-05 12:01:12.621000         bilyana.baycheva@sbnd.net
# 2  2019-12-16 17:16:53.040000           craig.bonafont@mews.com
# 3  2022-02-02 12:41:31.436000       marian.videka@mainstream.cz
# 4  2020-10-08 15:07:01.302000  joe.cockburn@scruffoftheneck.com
#
#   user.last_name user.first_name  account.users_count hubspot.job_title  \
# 0                   falk.kreuger                   49               NaN
# 1       Baycheva         Biliana                    1               NaN
# 2       Bonafont           Craig                   44               NaN
# 3         Videka   marian.videka                   96               NaN
# 4       Cockburn             Joe                   11               NaN
#
#   hubspot.industry hubspot.number_of_employees  salesforce.is_csda  \
# 0              NaN                         NaN               False
# 1              NaN                         NaN                True
# 2              NaN                         NaN               False
# 3              NaN                         NaN               False
# 4              NaN                         NaN               False
#
#   hubspot.country
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Fetch user_roles data
user_roles_df = get_user_roles_table(blob_service_client, today_str)
user_roles_df.head()
# Out:
#         user_roles._id.$oid    user_roles.userId.$oid  \
# 0  574e9259ed915d0006b985e5  574e9259ed915d0006b985e4
# 1  573e222fed915d0005cc2d07  573e222fed915d0005cc2d06
# 2  573d93d9ed915d00052efb6c  573d93d9ed915d00052efb6a
# 3  5746e3c8ed915d0005cc319c  5746e3c8ed915d0005cc319b
# 4  573f32bded915d0005cc2e5d  573f32bded915d0005cc2e5c
#
#      user_roles.roleId.$oid user_roles.accountId.$oid
# 0  573d93d9ed915d00052efb6b  574e9259ed915d0006b985e3
# 1  573d93d9ed915d00052efb6b  573e222fed915d0005cc2d05
# 2  573d93d9ed915d00052efb6b  573d93d9ed915d00052efb69
# 3  573d93d9ed915d00052efb6b  5746e3c8ed915d0005cc319a
# 4  573d93d9ed915d00052efb6b  573f32bded915d0005cc2e5b

# %%
# Fetch roles data
roles_df = get_roles_table(blob_service_client, today_str)
roles_df.head()
# Out:
#              roles._id.$oid             roles.name      roles.accountId.$oid
# 0  573dbb61ed915d0005cc2c4d                   user                       NaN
# 1  5a9f9cbee5274a0007acfcf9              Company B  57fb5f7bed915d0006582898
# 2  5b86ad85df457100079c04e4               Admin II  57fb5f7bed915d0006582898
# 3  5b8d2accf9159100080416a2  Air (bo's experiment)  573dbb12ed915d0005cc2c46
# 4  58f632d3ed915d0005e9ef6c              test role  58822288ed915d0005afa6ee

# %%
# Join user_roles with roles
user_roles_df = user_roles_df.merge(
    roles_df,
    how="left",
    left_on="user_roles.roleId.$oid",
    right_on="roles._id.$oid"
)

user_roles_df.head()
# Out:
#         user_roles._id.$oid    user_roles.userId.$oid  \
# 0  574e9259ed915d0006b985e5  574e9259ed915d0006b985e4
# 1  574e9259ed915d0006b985e5  574e9259ed915d0006b985e4
# 2  573e222fed915d0005cc2d07  573e222fed915d0005cc2d06
# 3  573e222fed915d0005cc2d07  573e222fed915d0005cc2d06
# 4  573d93d9ed915d00052efb6c  573d93d9ed915d00052efb6a
#
#      user_roles.roleId.$oid user_roles.accountId.$oid  \
# 0  573d93d9ed915d00052efb6b  574e9259ed915d0006b985e3
# 1  573d93d9ed915d00052efb6b  574e9259ed915d0006b985e3
# 2  573d93d9ed915d00052efb6b  573e222fed915d0005cc2d05
# 3  573d93d9ed915d00052efb6b  573e222fed915d0005cc2d05
# 4  573d93d9ed915d00052efb6b  573d93d9ed915d00052efb69
#
#              roles._id.$oid roles.name roles.accountId.$oid
# 0  573d93d9ed915d00052efb6b      admin                  NaN
# 1  573d93d9ed915d00052efb6b      admin                  NaN
# 2  573d93d9ed915d00052efb6b      admin                  NaN
# 3  573d93d9ed915d00052efb6b      admin                  NaN
# 4  573d93d9ed915d00052efb6b      admin                  NaN

# %%
unique_user_roles_df = get_roles_by_user(user_roles_df)
unique_user_roles_df.head()
# Out:
#      user_roles.userId.$oid                                              roles
# 0  573d9359ed915d00052efb10                                           SysAdmin
# 1  573d93d9ed915d00052efb6a                                              admin
# 2  573db6aeed915d0005cc2bc5                                              admin
# 3  573dbb12ed915d0005cc2c47  admin, user, user+, Ivan Osmak's team_7ba678c2...
# 4  573dbb61ed915d0005cc2c4c  admin, user, user+, Engineering_a8a9b5181dbd8f...

# %%
# Join df with user_roles_df
df = df.merge(
    unique_user_roles_df,
    how="left",
    left_on="user.id",
    right_on="user_roles.userId.$oid"
)

df.head()
# Out:
#                  account.id        account.name    account.date_created  \
# 0  5dbe9552fc535d0001015133              Advery 2019-11-03 08:52:34.305
# 1  5836fdcbed915d0007090826       Prime Holding 2016-11-24 00:00:00.000
# 2  5da59040f862dc0001f2ae06                Mews 2019-10-15 09:24:16.957
# 3  5b4c5eacf85c070007d02b68             Solitea 2018-07-16 09:00:28.255
# 4  5df25fa696e9cd00013ae7c0  Scruff of the Neck 2019-12-12 15:41:26.187
#
#   chargebee.status                   user.id user.language  \
# 0           active  615e05f268dff200012d0cf7        German
# 1           active  5be031087b36380001172075       English
# 2           active  5df7bc05b874bc00018dfdac       English
# 3           active  61fa7bfb5498de00013e1689       English
# 4           active  5f7f2b15f7d6770001587b27       English
#
#             user.date_created                        user.email  \
# 0  2021-10-06 20:24:18.590000          falk.kreuger@brueggli.ch
# 1  2018-11-05 12:01:12.621000         bilyana.baycheva@sbnd.net
# 2  2019-12-16 17:16:53.040000           craig.bonafont@mews.com
# 3  2022-02-02 12:41:31.436000       marian.videka@mainstream.cz
# 4  2020-10-08 15:07:01.302000  joe.cockburn@scruffoftheneck.com
#
#   user.last_name user.first_name  account.users_count hubspot.job_title  \
# 0                   falk.kreuger                   49               NaN
# 1       Baycheva         Biliana                    1               NaN
# 2       Bonafont           Craig                   44               NaN
# 3         Videka   marian.videka                   96               NaN
# 4       Cockburn             Joe                   11               NaN
#
#   hubspot.industry hubspot.number_of_employees  salesforce.is_csda  \
# 0              NaN                         NaN               False
# 1              NaN                         NaN                True
# 2              NaN                         NaN               False
# 3              NaN                         NaN               False
# 4              NaN                         NaN               False
#
#   hubspot.country    user_roles.userId.$oid  \
# 0             NaN  615e05f268dff200012d0cf7
# 1             NaN  5be031087b36380001172075
# 2             NaN  5df7bc05b874bc00018dfdac
# 3             NaN  61fa7bfb5498de00013e1689
# 4             NaN  5f7f2b15f7d6770001587b27
#
#                                                roles
# 0  user, Brüggli Medien Beratung_7fd187d76ecc9d87...
# 1  user, Design Team_e3167a16d7584dfa_MembersRole...
# 2  user, com_c65235d138f7e4d1_MembersRole, com_11...
# 3  user, EP_3f1ff9ee9d87831b_MembersRole, Mainstr...
# 4                                               user

# %%
df["roles"] = df["roles"].fillna("")
# df["user.is_okr_champion"] = df["roles"].map(lambda role: True if "champion" in (_role := role.lower()) or ("okr" in _role and "champion" in _role) else False)

# %%
# Drop unnecessary columns
"""
Should I drop all id's?
account.id
user.id

user_roles._id.$oid
user_roles.userId.$oid
user_roles.roleId.$oid
user_roles.accountId.$oid
roles._id.$oid
roles.accountId.$oid

"""

df = df[
    df.columns[
        ~df.columns.isin(
            [
                "account.id",
                "user.id",
                "user_roles._id.$oid",
                "user_roles.userId.$oid",
                "user_roles.roleId.$oid",
                "user_roles.accountId.$oid",
                "roles._id.$oid",
                "roles.accountId.$oid"
            ]
        )
    ]
]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   account.name                 250 non-null    object
#  1   account.date_created         250 non-null    datetime64[ns]
#  2   chargebee.status             250 non-null    object
#  3   user.language                250 non-null    object
#  4   user.date_created            250 non-null    object
#  5   user.email                   250 non-null    object
#  6   user.last_name               250 non-null    object
#  7   user.first_name              250 non-null    object
#  8   account.users_count          250 non-null    int64
#  9   hubspot.job_title            45 non-null     object
#  10  hubspot.industry             40 non-null     object
#  11  hubspot.number_of_employees  68 non-null     object
#  12  salesforce.is_csda           250 non-null    bool
#  13  hubspot.country              72 non-null     object
#  14  roles                        250 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(12)
# memory usage: 29.5+ KB

# %%
df["user.date_created"] = df["user.date_created"].astype("datetime64[ns]")
df["account.date_created"] = df["account.date_created"].astype("datetime64[ns]")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 249
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   account.name                 250 non-null    object
#  1   account.date_created         250 non-null    datetime64[ns]
#  2   chargebee.status             250 non-null    object
#  3   user.language                250 non-null    object
#  4   user.date_created            250 non-null    datetime64[ns]
#  5   user.email                   250 non-null    object
#  6   user.last_name               250 non-null    object
#  7   user.first_name              250 non-null    object
#  8   account.users_count          250 non-null    int64
#  9   hubspot.job_title            45 non-null     object
#  10  hubspot.industry             40 non-null     object
#  11  hubspot.number_of_employees  68 non-null     object
#  12  salesforce.is_csda           250 non-null    bool
#  13  hubspot.country              72 non-null     object
#  14  roles                        250 non-null    object
# dtypes: bool(1), datetime64[ns](2), int64(1), object(11)
# memory usage: 29.5+ KB

# %%
df.head()
# Out:
#          account.name    account.date_created chargebee.status user.language  \
# 0              Advery 2019-11-03 08:52:34.305           active        German
# 1       Prime Holding 2016-11-24 00:00:00.000           active       English
# 2                Mews 2019-10-15 09:24:16.957           active       English
# 3             Solitea 2018-07-16 09:00:28.255           active       English
# 4  Scruff of the Neck 2019-12-12 15:41:26.187           active       English
#
#         user.date_created                        user.email user.last_name  \
# 0 2021-10-06 20:24:18.590          falk.kreuger@brueggli.ch
# 1 2018-11-05 12:01:12.621         bilyana.baycheva@sbnd.net       Baycheva
# 2 2019-12-16 17:16:53.040           craig.bonafont@mews.com       Bonafont
# 3 2022-02-02 12:41:31.436       marian.videka@mainstream.cz         Videka
# 4 2020-10-08 15:07:01.302  joe.cockburn@scruffoftheneck.com       Cockburn
#
#   user.first_name  account.users_count hubspot.job_title hubspot.industry  \
# 0    falk.kreuger                   49               NaN              NaN
# 1         Biliana                    1               NaN              NaN
# 2           Craig                   44               NaN              NaN
# 3   marian.videka                   96               NaN              NaN
# 4             Joe                   11               NaN              NaN
#
#   hubspot.number_of_employees  salesforce.is_csda hubspot.country  \
# 0                         NaN               False             NaN
# 1                         NaN                True             NaN
# 2                         NaN               False             NaN
# 3                         NaN               False             NaN
# 4                         NaN               False             NaN
#
#                                                roles
# 0  user, Brüggli Medien Beratung_7fd187d76ecc9d87...
# 1  user, Design Team_e3167a16d7584dfa_MembersRole...
# 2  user, com_c65235d138f7e4d1_MembersRole, com_11...
# 3  user, EP_3f1ff9ee9d87831b_MembersRole, Mainstr...
# 4                                               user

# %%
# Format datetime fields as string for output file
df["account.date_created"] = df["account.date_created"].dt.strftime("%Y/%m/%d")
df["user.date_created"] = df["user.date_created"].dt.strftime("%Y/%m/%d")

# %%
df.shape
# Out:
# (250, 15)

# %%
# Save data to csv file
df.to_csv(f"sample_users_180+days_data_{datetime_string(today, '-')}.csv", index=False)
